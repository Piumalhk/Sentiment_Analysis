# %%
import numpy as np

# %%
import json 
with open ('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'piumalharshana', 'key': '648aee1b2cd9030f0e1d308249d3334a'}

# %%
# !pip install kaggle
# Out:
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#
#    ---------------------------------------- 0/5 [text-unidecode]
#    ---------------------------------------- 0/5 [text-unidecode]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    -------- ------------------------------- 1/5 [tqdm]
#    ---------------- ----------------------- 2/5 [python-slugify]
#    ---------------- ----------------------- 2/5 [python-slugify]
#    ------------------------ --------------- 3/5 [protobuf]
#    ------------------------ --------------- 3/5 [protobuf]
# ...

# %%
import os 
os.environ['piumalharshana'] = data['username']
os.environ['648aee1b2cd9030f0e1d308249d3334a'] = data['key']

# %%
import os
import json
from kaggle.api.kaggle_api_extended import KaggleApi

# 🔹 Path to your kaggle.json inside artifacts folder
path = r"F:\Project\Sentiment_Analysis\artifacts\kaggle.json"

# 🔹 Load username and key
with open(path, "r") as f:
    token = json.load(f)

# 🔹 Set environment variables manually
os.environ['KAGGLE_USERNAME'] = token['username']
os.environ['KAGGLE_KEY'] = token['key']

# 🔹 Initialize API
api = KaggleApi()
api.authenticate()

print("✅ Kaggle API authenticated successfully!")
# Out:
# ✅ Kaggle API authenticated successfully!

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset',path='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
